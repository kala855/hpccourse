# %% [markdown]
# # <span style="color:green">Objective</span>
# <div style="text-align:justify;font-size:20px">
# <body>
# Learn to write a high performance kernel by privatizing outputs
# <ul>
# <li>Privatization as a technique for reducing latency, increasing
# throughput, and reducing serialization</li>
# <li>A high performance privatized histogram kernel</li>
# <li>Practical example of using shared memory and L2 cache atomic
# operations</li>
# </ul>
# </body>
# </div>
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Privatization</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/1.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Privatization (cont.)</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/2.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Privatization (cont.)</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/3.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Cost and Benefit of Privatization</span>
#
# <br></br>
# <div style="text-align:justify;font-size:20px">
#         <ul>
#             <body>
#
#             <li>Cost
#                 <ul>
#                     <li>Overhead for creating and initializing private copies</li>
#                     <li>Overhead for accumulating the contents of private copies into the final copy</li>
#                 </ul>
#             </li>
#             <li>Benefit
#                 <ul>
#                     <li>Much less contention and serialization in accessing both the private copies and the
# final copy</li>
#                     <li>The overall performance can often be improved more than 10x</li>
#                 </ul>
#             </li>
#             </body>
#         </ul>
# </div>
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Shared Memory Atomics for Histogram</span>
#
# <br></br>
# <div style="text-align:justify;font-size:20px">
#         <ul>
#             <body>
#
#             <li>Each subset of threads are in the same block</li>
#             <li>Much higher throughput than DRAM (100x) or L2 (10x) atomics</li>
#             <li>Less contention – only threads in the same block can access a
# shared memory variable</li>
#             <li>This is a very important use case for shared memory!</li>
#             </body>
#         </ul>
# </div>
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Shared Memory Atomics Requires Privatization</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/4.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Shared Memory Atomics Requires Privatization</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/5.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Build Private Histogram</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/6.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
#
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">Build Final Histogram</span>
#
# <br></br>
# <span style="float:left;clear:center">![alt tag](img/7.png)</span>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
# <br></br>
#
# <br></br>
# <br></br>
# <br></br>
#
#
#
# <hr style="height:2px">

# %% [markdown]
# # <span style="color:green">More on Privatization</span>
#
# <br></br>
# <div style="text-align:justify;font-size:20px">
#         <ul>
#             <body>
#             <li>Privatization is a powerful and frequently used technique for
# parallelizing applications</li>
#             <br></br>
#             <li>The operation needs to be associative and commutative
#                 <ul>
#                     <li>Histogram add operation is associative and commutative</li>
#                     <li>No privatization if the operation does not fit the requirement</li>
#                 </ul>
#             </li>
#             <br></br>
#             <li>The private histogram size needs to be small
#                 <ul>
#                     <li>Fits into shared memory</li>
#                 </ul>
#             </li>
#             <br></br>
#             <li>What if the histogram is too large to privatize?
#                 <ul>
#                     <li>Sometimes one can partially privatize an output histogram and use range
# testing to go to either global memory or shared memory</li>
#                 </ul>
#             </li>
#             </body>
#         </ul>
# </div>
#
# <hr style="height:2px">

# %% [markdown]
# <footer>
# <cite> GPU NVIDIA Teaching Kit - University of Illinois </cite>
# </footer>
# <hr style="height:2px">
